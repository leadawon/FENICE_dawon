# %%
dataset_name = "frank"

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_rouge_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)



# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
# Score 값 정규화 (Min-Max Scaling)
#scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

labels = np.array([entry["label"] for entry in data])
# Compute ROC-AUC
roc_auc = roc_auc_score(labels, scores)

# Plot ROC Curve
fpr, tpr, _ = roc_curve(labels, scores)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()

print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# ROC-AUC Score: 0.8041

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_rouge_sbert_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)



# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
# Score 값 정규화 (Min-Max Scaling)
#scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

labels = np.array([entry["label"] for entry in data])
# Compute ROC-AUC
roc_auc = roc_auc_score(labels, scores)

# Plot ROC Curve
fpr, tpr, _ = roc_curve(labels, scores)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()

print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# ROC-AUC Score: 0.8037

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_sbert_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)



# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
# Score 값 정규화 (Min-Max Scaling)
#scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))

labels = np.array([entry["label"] for entry in data])
# Compute ROC-AUC
roc_auc = roc_auc_score(labels, scores)

# Plot ROC Curve
fpr, tpr, _ = roc_curve(labels, scores)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label=f'ROC-AUC = {roc_auc:.4f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()

print(f"ROC-AUC Score: {roc_auc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 9
#       6 # Load the data from the JSON file
#       7 file_path = f"../results/{dataset_name}/fenice_sbert_coarse.json"
# ----> 9 with open(file_path, "r") as f:
#      10     data = json.load(f)
#      14 # Extract scores and labels
#
# File /workspace/venvs/FENICERSBvenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/frank/fenice_sbert_coarse.json'

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_rouge_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)

# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
labels = np.array([entry["label"] for entry in data])

# PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# 랜덤 분류기 PR-AUC 계산
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

print(f"PR-AUC (Model): {pr_auc:.4f}")
print(f"PR-AUC (Random): {random_pr_auc:.4f}")
# Out:
# PR-AUC (Model): 0.5992
# PR-AUC (Random): 0.3339

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_rouge_sbert_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)

# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
labels = np.array([entry["label"] for entry in data])

# PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# 랜덤 분류기 PR-AUC 계산
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

print(f"PR-AUC (Model): {pr_auc:.4f}")
print(f"PR-AUC (Random): {random_pr_auc:.4f}")
# Out:
# PR-AUC (Model): 0.5954
# PR-AUC (Random): 0.3070

# %%
from sklearn.metrics import precision_recall_curve, auc
import json
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the JSON file
file_path = f"../results/{dataset_name}/fenice_sbert_coarse.json"

with open(file_path, "r") as f:
    data = json.load(f)

# Extract scores and labels
scores = np.array([entry["score"] for entry in data])
labels = np.array([entry["label"] for entry in data])

# PR-AUC 계산 (모델)
precision, recall, _ = precision_recall_curve(labels, scores)
pr_auc = auc(recall, precision)

# 랜덤 분류기 PR-AUC 계산
random_scores = np.random.rand(len(labels))
random_precision, random_recall, _ = precision_recall_curve(labels, random_scores)
random_pr_auc = auc(random_recall, random_precision)

# PR Curve Plot
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label=f'PR-AUC (Model) = {pr_auc:.4f}')
plt.plot(random_recall, random_precision, linestyle='--', color='red', label=f'PR-AUC (Random) = {random_pr_auc:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

print(f"PR-AUC (Model): {pr_auc:.4f}")
print(f"PR-AUC (Random): {random_pr_auc:.4f}")
