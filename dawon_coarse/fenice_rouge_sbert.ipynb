# %%
#here is coarse

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=0.5)

# Load the xsumfaith.json file
with open('../dawon_org/xsumfaith_short.json', 'r', encoding="utf-8") as f:
    xsumfaith_data = json.load(f)
xsumfaith_data = xsumfaith_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/xsumfaith/fenice_rouge_sbert_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(xsumfaith_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/xsumfaith/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(xsumfaith_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/xsumfaith/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=0.5)

# Load the xsumfaith.json file
with open('../dawon_org/frank_short.json', 'r', encoding="utf-8") as f:
    frank_data = json.load(f)
frank_data = frank_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/frank/fenice_rouge_sbert_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(frank_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/frank/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(frank_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/frank/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=0.5)

# Load the xsumfaith.json file
with open('../dawon_org/cogensumm_short.json', 'r', encoding="utf-8") as f:
    cogensumm_data = json.load(f)
cogensumm_data = cogensumm_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/cogensumm/fenice_rouge_sbert_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(cogensumm_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/cogensumm/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(cogensumm_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/cogensumm/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      16 for i, item in enumerate(cogensumm_data):
#      17     batch = [{"document": item["document"], "summary": item["claim"]}]
# ---> 18     result = fenice.score_batch(batch)
#      20     # 저장할 데이터 구조
#      21     result_entry = {
#      22         "score": result[0]["score"],
#      23         "label": item["label"],
#      24         "document": item["document"],
#      25         "summary": item["claim"]
#      26     }
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:167, in score_batch(self, batch)
#     165     all_pairs = [(x, hypothesis) for x in premises]
#     166     self.cache_alignment(alignments_ids, all_pairs)
# --> 167     alignment, _ = self.load_alignment(
#     168         alignments_ids=alignments_ids, premises=premises, hypothesis=hypothesis
#     169     )
#     170 else:
#     171     alignment, _ = loaded_alignment
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:189, in cache(self, documents, summaries)
#     186 del self.nli_aligner
#     187 torch.cuda.empty_cache()
# --> 189 return predictions
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:224, in cache_claims(self, summaries)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/claim_extractor/claim_extractor.py:28, in ClaimExtractor.process_batch(self, batch)
#      24 for b in tqdm(batches, desc="Extracting claims..."):
#      25     tok_input = self.tokenizer.batch_encode_plus(
#      26         b, return_tensors="pt", padding=True
#      27     ).to(self.device)
# ---> 28     claims = self.model.generate(**tok_input)
#      29     claims = self.tokenizer.batch_decode(claims, skip_special_tokens=True)
#      30     claims = [split_into_sentences(c) for c in claims]
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/generation/utils.py:1626, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1619     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1620         input_ids=input_ids,
#    1621         expand_size=generation_config.num_beams,
#    1622         is_encoder_decoder=self.config.is_encoder_decoder,
#    1623         **model_kwargs,
#    1624     )
#    1625     # 13. run beam search
# -> 1626     return self.beam_search(
#    1627         input_ids,
#    1628         beam_scorer,
#    1629         logits_processor=prepared_logits_processor,
#    1630         stopping_criteria=prepared_stopping_criteria,
#    1631         pad_token_id=generation_config.pad_token_id,
#    1632         eos_token_id=generation_config.eos_token_id,
#    1633         output_scores=generation_config.output_scores,
#    1634         output_logits=generation_config.output_logits,
#    1635         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1636         synced_gpus=synced_gpus,
#    1637         sequential=generation_config.low_memory,
#    1638         **model_kwargs,
#    1639     )
#    1641 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1642     # 11. prepare logits warper
#    1643     logits_warper = self._get_logits_warper(generation_config)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/generation/utils.py:3068, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, sequential, **model_kwargs)
#    3065     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3067 else:  # Unchanged original behavior
# -> 3068     outputs = self(
#    3069         **model_inputs,
#    3070         return_dict=True,
#    3071         output_attentions=output_attentions,
#    3072         output_hidden_states=output_hidden_states,
#    3073     )
#    3075 if synced_gpus and this_peer_finished:
#    3076     cur_len = cur_len + 1
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1748, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1745         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1747 # Decode
# -> 1748 decoder_outputs = self.decoder(
#    1749     input_ids=decoder_input_ids,
#    1750     attention_mask=decoder_attention_mask,
#    1751     inputs_embeds=decoder_inputs_embeds,
#    1752     past_key_values=past_key_values,
#    1753     encoder_hidden_states=hidden_states,
#    1754     encoder_attention_mask=attention_mask,
#    1755     head_mask=decoder_head_mask,
#    1756     cross_attn_head_mask=cross_attn_head_mask,
#    1757     use_cache=use_cache,
#    1758     output_attentions=output_attentions,
#    1759     output_hidden_states=output_hidden_states,
#    1760     return_dict=return_dict,
#    1761 )
#    1763 sequence_output = decoder_outputs[0]
#    1765 # Set device for model parallelism
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:1115, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1100     layer_outputs = self._gradient_checkpointing_func(
#    1101         layer_module.forward,
#    1102         hidden_states,
#    (...)
#    1112         output_attentions,
#    1113     )
#    1114 else:
# -> 1115     layer_outputs = layer_module(
#    1116         hidden_states,
#    1117         attention_mask=extended_attention_mask,
#    1118         position_bias=position_bias,
#    1119         encoder_hidden_states=encoder_hidden_states,
#    1120         encoder_attention_mask=encoder_extended_attention_mask,
#    1121         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1122         layer_head_mask=layer_head_mask,
#    1123         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1124         past_key_value=past_key_value,
#    1125         use_cache=use_cache,
#    1126         output_attentions=output_attentions,
#    1127     )
#    1129 # layer_outputs is a tuple with:
#    1130 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1131 if use_cache is False:
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:725, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     722 else:
#     723     query_length = None
# --> 725 cross_attention_outputs = self.layer[1](
#     726     hidden_states,
#     727     key_value_states=encoder_hidden_states,
#     728     attention_mask=encoder_attention_mask,
#     729     position_bias=encoder_decoder_position_bias,
#     730     layer_head_mask=cross_attn_layer_head_mask,
#     731     past_key_value=cross_attn_past_key_value,
#     732     query_length=query_length,
#     733     use_cache=use_cache,
#     734     output_attentions=output_attentions,
#     735 )
#     736 hidden_states = cross_attention_outputs[0]
#     738 # clamp inf values to enable fp16 training
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:636, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     623 def forward(
#     624     self,
#     625     hidden_states,
#    (...)
#     633     output_attentions=False,
#     634 ):
#     635     normed_hidden_states = self.layer_norm(hidden_states)
# --> 636     attention_output = self.EncDecAttention(
#     637         normed_hidden_states,
#     638         mask=attention_mask,
#     639         key_value_states=key_value_states,
#     640         position_bias=position_bias,
#     641         layer_head_mask=layer_head_mask,
#     642         past_key_value=past_key_value,
#     643         use_cache=use_cache,
#     644         query_length=query_length,
#     645         output_attentions=output_attentions,
#     646     )
#     647     layer_output = hidden_states + self.dropout(attention_output[0])
#     648     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/models/t5/modeling_t5.py:521, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     518     return hidden_states
#     520 # get query states
# --> 521 query_states = shape(self.q(hidden_states))  # (batch_size, n_heads, seq_length, dim_per_head)
#     523 # get key/value states
#     524 key_states = project(
#     525     hidden_states, self.k, key_value_states, past_key_value[0] if past_key_value is not None else None
#     526 )
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=0.5)

# Load the xsumfaith.json file
with open('../dawon_org/factcc_short.json', 'r', encoding="utf-8") as f:
    factcc_data = json.load(f)
factcc_data = factcc_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/factcc/fenice_rouge_sbert_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(factcc_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/factcc/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(factcc_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/factcc/fenice_rouge_sbert_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")
