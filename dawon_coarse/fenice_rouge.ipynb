# %%
### here is coarse

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=1)

# Load the xsumfaith.json file
with open('../dawon_org/xsumfaith_short.json', 'r', encoding="utf-8") as f:
    xsumfaith_data = json.load(f)
xsumfaith_data = xsumfaith_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/xsumfaith/fenice_rouge_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(xsumfaith_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/xsumfaith/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(xsumfaith_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/xsumfaith/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=1)

# Load the xsumfaith.json file
with open('../dawon_org/frank_short.json', 'r', encoding="utf-8") as f:
    frank_data = json.load(f)
frank_data = frank_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/frank/fenice_rouge_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(frank_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/frank/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(frank_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/frank/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=1)

# Load the xsumfaith.json file
with open('../dawon_org/cogensumm_short.json', 'r', encoding="utf-8") as f:
    cogensumm_data = json.load(f)
cogensumm_data = cogensumm_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/cogensumm/fenice_rouge_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(cogensumm_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/cogensumm/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(cogensumm_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/cogensumm/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      16 for i, item in enumerate(cogensumm_data):
#      17     batch = [{"document": item["document"], "summary": item["claim"]}]
# ---> 18     result = fenice.score_batch(batch)
#      20     # 저장할 데이터 구조
#      21     result_entry = {
#      22         "score": result[0]["score"],
#      23         "label": item["label"],
#      24         "document": item["document"],
#      25         "summary": item["claim"]
#      26     }
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:167, in score_batch(self, batch)
#     165     all_pairs = [(x, hypothesis) for x in premises]
#     166     self.cache_alignment(alignments_ids, all_pairs)
# --> 167     alignment, _ = self.load_alignment(
#     168         alignments_ids=alignments_ids, premises=premises, hypothesis=hypothesis
#     169     )
#     170 else:
#     171     alignment, _ = loaded_alignment
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:196, in cache(self, documents, summaries)
#     187     torch.cuda.empty_cache()
#     189     return predictions
#     191 def cache(self, documents, summaries):
#     192     # self.cache_sentences(documents)
#     193     # if self.use_coref:
#     194     #     self.cache_coref(documents)
#     195     # self.cache_claims(summaries)
# --> 196     # 여기 순서만 조금 바꿈 here
#     197
#     198     # 여기 주석해제하고 summary 확인하기ㄴ
#     199     claims = self.cache_claims(summaries)
#     200     self.cache_sentences(documents=documents, claims=claims)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:291, in cache_alignments(self, documents, summaries)
#     280 alignments_ids, all_pairs = self.compute_nli_pairs(
#     281     alignments_ids, all_pairs, claims, sample_id, sentences
#     282 )
#     283 if self.paragraph_level_nli:
#     284     alignments_ids, all_pairs = self.compute_nli_pairs(
#     285         alignments_ids,
#     286         all_pairs,
#     287         claims,
#     288         sample_id,
#     289         paragraphs,
#     290         prefix="par",
# --> 291     )
#     292 if self.doc_level_nli:
#     293     alignment_ids_doc, all_pairs_doc = self.compute_nli_pairs(
#     294         alignment_ids_doc,
#     295         all_pairs_doc,
#    (...)
#     299         prefix="doc",
#     300     )
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:328, in cache_alignment(self, alignments_ids, all_pairs, disable_prog_bar)
#     317             all_pairs.append((premise, claim))
#     318     return alignments_ids, all_pairs
#     320 def get_alignment_id(
#     321     self,
#     322     sample_id: int,
#     323     premise_id: int,
#     324     hypothesis_id: int,
#     325     premise: str,
#     326     alignment_prefix: Optional[str] = None,
#     327     k_chars: int = 100,
# --> 328 ):
#     330     id = f"{sample_id}-{premise_id}-{hypothesis_id}-{premise[:k_chars]}"
#     331     if alignment_prefix is not None:
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/nli/nli_aligner.py:46, in NLIAligner.process_batch(self, prem_hyp_pairs, disable_prog_bar)
#      39 all_neutral_probs = []
#      40 for batch in tqdm(
#      41     batches,
#      42     desc="Computing alignments...",
#      43     total=len(batches),
#      44     disable=disable_prog_bar,
#      45 ):
# ---> 46     entailment_dists = self.score_sample(batch)
#      47     all_entailment_probs.extend([d[0] for d in entailment_dists])
#      48     all_neutral_probs.extend([d[1] for d in entailment_dists])
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/nli/nli_aligner.py:60, in NLIAligner.score_sample(self, batch)
#      52 def score_sample(self, batch):
#      53     tokenized_input_seq_pairs = self.tokenizer.batch_encode_plus(
#      54         batch,
#      55         return_token_type_ids=True,
#      56         padding=True,
#      57         return_tensors="pt",
#      58         truncation=True,
#      59         max_length=self.max_length,
# ---> 60     ).to(self.device)
#      61     input_ids = tokenized_input_seq_pairs["input_ids"]
#      62     token_type_ids = tokenized_input_seq_pairs["token_type_ids"]
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:789, in BatchEncoding.to(self, device)
#     785 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     786 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     787 # into a HalfTensor
#     788 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 789     self.data = {k: v.to(device=device) for k, v in self.data.items()}
#     790 else:
#     791     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:789, in <dictcomp>(.0)
#     785 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     786 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     787 # into a HalfTensor
#     788 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 789     self.data = {k: v.to(device=device) for k, v in self.data.items()}
#     790 else:
#     791     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# KeyboardInterrupt:

# %%
# %%capture
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import json
from metric.FENICE import FENICE
import time
fenice = FENICE(rouge_ratio=1)

# Load the xsumfaith.json file
with open('../dawon_org/factcc_short.json', 'r', encoding="utf-8") as f:
    factcc_data = json.load(f)
factcc_data = factcc_data#[88:]
# JSON 파일을 새로 생성 (초기화)
with open('../results/factcc/fenice_rouge_coarse.json', 'w', encoding="utf-8") as f:
    f.write("[\n")  # JSON 배열 시작
# Compute the scores for each document-summary pair
for i, item in enumerate(factcc_data):
    batch = [{"document": item["document"], "summary": item["claim"]}]
    result = fenice.score_batch(batch)

    # 저장할 데이터 구조
    result_entry = {
        "score": result[0]["score"],
        "label": item["label"],
        "document": item["document"],
        "summary": item["claim"]
    }

    # JSON 파일에 한 줄씩 추가 (마지막 요소인지 확인하여 쉼표 처리)
    with open('../results/factcc/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
        json.dump(result_entry, f, indent=4)
        if i < len(factcc_data) - 1:  # 마지막 요소가 아니면 쉼표 추가
            f.write(",\n")

# JSON 파일 닫기 (배열 닫기)
with open('../results/factcc/fenice_rouge_coarse.json', 'a', encoding="utf-8") as f:
    f.write("\n]")

print("Results saved to fenice_original.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 18
#      16 for i, item in enumerate(factcc_data):
#      17     batch = [{"document": item["document"], "summary": item["claim"]}]
# ---> 18     result = fenice.score_batch(batch)
#      20     # 저장할 데이터 구조
#      21     result_entry = {
#      22         "score": result[0]["score"],
#      23         "label": item["label"],
#      24         "document": item["document"],
#      25         "summary": item["claim"]
#      26     }
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:166, in FENICE.score_batch(self, batch)
#     164 documents = [el["document"] for el in batch]
#     165 summaries = [el["summary"] for el in batch]
# --> 166 self.cache(documents, summaries)
#     167 predictions = []
#     168 for sample_id, (doc, summary) in tqdm(
#     169     enumerate(zip(documents, summaries)),
#     170     total=len(documents),
#     171     desc="Computing FENICE...",
#     172 ):
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:189, in FENICE.cache(self, documents, summaries)
#     180 def cache(self, documents, summaries):
#     181     # self.cache_sentences(documents)
#     182     # if self.use_coref:
#    (...)
#     186
#     187     # 여기 주석해제하고 summary 확인하기ㄴ
#     188     claims = self.cache_claims(summaries)
# --> 189     self.cache_sentences(documents=documents, claims=claims)
#     190     if self.use_coref:
#     191         self.cache_coref(documents)
#
# File /workspace/venvs/FENICECOARSEvenv/lib/python3.10/site-packages/metric/FENICE.py:204, in FENICE.cache_sentences(self, documents, claims)
#     202 id = self.get_id(i, documents[i])
#     203 self.sentences_cache[id] = mod_sentences  # 전체 문장 (atomic 포함)
# --> 204 self.original_sentences_cache[id] = ori_sentences
#
# AttributeError: 'FENICE' object has no attribute 'original_sentences_cache'
